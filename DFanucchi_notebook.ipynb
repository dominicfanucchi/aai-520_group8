# %% [markdown]
# Importing necessary libraries and packages

# %%
# Standard library imports
import os
import random
import warnings
import json

# Data processing and numerical operations
import pandas as pd
import numpy as np
from datasets import load_dataset  # Dataset handling

# Data visualization
import seaborn as sns
import matplotlib.pyplot as plt
from prettytable import PrettyTable
# %matplotlib inline

# Machine learning and preprocessing
# from sklearn.preprocessing import 
# from sklearn.model_selection import 
# from sklearn.metrics import 

# Deep learning frameworks
import torch as pt

# Progress bar
from tqdm import tqdm

# Configure plotting
plt.style.use('fivethirtyeight')
sns.set_theme(style='whitegrid', palette='deep')

# Suppress warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# Checking for GPU availability
device = pt.device('cuda' if pt.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# **Dataset Summary**
# Stanford Question Answering Dataset (SQuAD) is a reading comprehension dataset, consisting of questions posed by crowdworkers on a set of Wikipedia articles, where the answer to every question is a segment of text, or span, from the corresponding reading passage, or the question might be unanswerable.
#
# SQuAD 1.1 contains 100,000+ question-answer pairs on 500+ articles.
#
#
# **Dataset Structure**
# An example of 'train' looks as follows.
#
#     {
#         "answers": {
#             "answer_start": [1],
#             "text": ["This is a test text"]
#         },
#         "context": "This is a test context.",
#         "id": "1",
#         "question": "Is this a test?",
#         "title": "train test"
#     }
#
#
# **plain_text**
# - id: a string feature.
# - title: a string feature.
# - context: a string feature.
# - question: a string feature.
# - answers: a dictionary feature containing:
#     - text: a string feature.
#     - answer_start: a int32 feature.

# %%
squad_dataset = load_dataset('squad')

train_data = squad_dataset['train']
validation_data = squad_dataset['validation']

print(f'Train data size: {len(train_data)}')
print(f'Validation data size: {len(validation_data)}')

print(train_data.column_names)
# Out:
# Train data size: 87599
# Validation data size: 10570
# ['id', 'title', 'context', 'question', 'answers']

# %% [markdown]
# Lets look at an example entry to see what we are dealing with

# %%
example = json.dumps(train_data[0], indent=4)
print(example)
# Out:
# {
#     "id": "5733be284776f41900661182",
#     "title": "University_of_Notre_Dame",
#     "context": "Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend \"Venite Ad Me Omnes\". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.",
#     "question": "To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?",
#     "answers": {
#         "text": [
#             "Saint Bernadette Soubirous"
#         ],
#         "answer_start": [
#             515
#         ]
#     }
# }

# %% [markdown]
# Let's perform some EDA to help gain some insights into the structure and characteristics of the data

# %%
context_lengths = [len(ex['context']) for ex in train_data]
plt.figure(figsize=(10,6))
sns.histplot(context_lengths, bins=50)
plt.title('Distribution of Context Lengths')
plt.xlabel('Context Length')
plt.ylabel('Frequency')
plt.show()

# %%
question_lengths = [len(ex['question']) for ex in train_data]
print(question_lengths[:10])
print(f"Max question length: {max(question_lengths)}")
print(f"Min question length: {min(question_lengths)}")
print(f"Mean question length: {np.mean(question_lengths)}")
# Out:
# [71, 49, 76, 33, 52, 64, 48, 53, 53, 80]
# Max question length: 25651
# Min question length: 1
# Mean question length: 59.57113665681115

# %% [markdown]
# Notice the extremely large `max question length` above, we should investigate so we can identify this outlier in our training data

# %%
long_questions_with_indices = [(i, ex) for i, ex in enumerate(train_data) if len(ex['question']) > 1000]
print(f"Number of questions longer than 1000 characters: {len(long_questions_with_indices)}")

for index, q in long_questions_with_indices[:5]:
    print(f"Index: {index}, Question: {q['question']} (Length: {len(q['question'])})")
# Out:
# Number of questions longer than 1000 characters: 1
# Index: 75237, Question:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...

# %% [markdown]
# While we can't actually see it, this question is quite short but contains a large amount of whitespace

# %%
# Exclude the question at index 75237
filtered_data = [ex for i, ex in enumerate(train_data) if i != 75237]

question_lengths = [len(ex['question']) for ex in filtered_data]

plt.figure(figsize=(10, 6))
sns.histplot(question_lengths, bins=250)
plt.title('Distribution of Question Lengths (Excluding Index 75237)')
plt.xlabel('Question Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Let's define a function to print out any dataset entry at will since our data is in JSON format. We also could have a shorter implementation but I decided to print out the data fields explicitly

# %%
answer_lengths = [len(ex['answers']['text'][0]) for ex in train_data]
plt.figure(figsize=(10,6))
sns.histplot(answer_lengths, bins=30)
plt.title('Distribution of Answer Lengths')
plt.xlabel('Answer Length')
plt.ylabel('Frequency')
plt.show()

# %%
def print_entries(dataset, num_entries=1):
    num_entries = min(num_entries, len(dataset))

    for index in range(num_entries):
        data = dataset[index]

        print(f"Entry {index + 1}:\n")
        print(f"ID: {data['id']}")
        print(f"Title: {data['title']}")
        print(f"Context: {data['context']}")
        print(f"Question: {data['question']}")
        print(f"Answers: {data['answers']['text']}")
        print("\n")

# %%
print_entries(train_data, 5)
# Out:
# Entry 1:
#
# ID: 5733be284776f41900661182
# Title: University_of_Notre_Dame
# Context: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# Question: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Answers: ['Saint Bernadette Soubirous']
#
#
# Entry 2:
#
# ID: 5733be284776f4190066117f
# Title: University_of_Notre_Dame
# Context: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# Question: What is in front of the Notre Dame Main Building?
# Answers: ['a copper statue of Christ']
#
#
# Entry 3:
#
# ID: 5733be284776f41900661180
# Title: University_of_Notre_Dame
# Context: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# Question: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Answers: ['the Main Building']
#
#
# Entry 4:
#
# ID: 5733be284776f41900661181
# Title: University_of_Notre_Dame
# Context: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# Question: What is the Grotto at Notre Dame?
# Answers: ['a Marian place of prayer and reflection']
#
#
# Entry 5:
#
# ID: 5733be284776f4190066117e
# Title: University_of_Notre_Dame
# Context: Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
# Question: What sits on top of the Main Building at Notre Dame?
# Answers: ['a golden statue of the Virgin Mary']

# %% [markdown]
# From the above print out of the first 5 entries in our train_data, they all have the same context, but different questions and obviously different answers.
#
# I wonder if this structure would yield better results if the context was not repeated so often. Anyways, the below code shows the amount of unique "context" in our data.

# %%
unique_titles = train_data.unique('title')
print(f"Number of unique titles in train data: {len(unique_titles)}")

unique_context = train_data.unique('context')
print(f'Number of unique "context" in train data: {len(unique_context)}')
# Out:
# Number of unique titles in train data: 442
# Number of unique "context" in train data: 18891

# %% [markdown]
# Taking this a step further, lets see how many "contexts" belong to each "title" and then how many questions belong to each unique context.

# %%
from collections import defaultdict

title_context_question_count = defaultdict(lambda: {"contexts": set(), "total_questions": 0})

# iterate through data
for entry in train_data:
    title = entry['title']
    context = entry['context']
    title_context_question_count[title]["contexts"].add(context)
    title_context_question_count[title]["total_questions"] += 1

# creating a PrettyTable object
table = PrettyTable(["Title", "# of Contexts", "# of Questions"])

# populating the table
for title, counts in title_context_question_count.items():
    table.add_row([title, len(counts['contexts']), counts['total_questions']])

print(table)
# Out:
# +-------------------------------------------------------------+---------------+----------------+
# |                            Title                            | # of Contexts | # of Questions |
# +-------------------------------------------------------------+---------------+----------------+
# |                   University_of_Notre_Dame                  |       55      |      269       |
# |                           Beyoncé                           |       66      |      758       |
# |                           Montana                           |       44      |      150       |
# |                           Genocide                          |       26      |      137       |
# |                         Antibiotics                         |       26      |      169       |
# |                       Frédéric_Chopin                       |       82      |      697       |
# |        Sino-Tibetan_relations_during_the_Ming_dynasty       |       72      |      291       |
# |                             IPod                            |       60      |      327       |
# |            The_Legend_of_Zelda:_Twilight_Princess           |       32      |      214       |
# |                     Spectre_(2015_film)                     |       43      |      274       |
# |                   2008_Sichuan_earthquake                   |       77      |      521       |
# |                        New_York_City                        |      148      |      817       |
# |                    To_Kill_a_Mockingbird                    |       62      |      228       |
# |                         Solar_energy                        |       52      |      250       |
# |                          Tajikistan                         |       32      |      154       |
# |                         Anthropology                        |       45      |      222       |
# |                           Portugal                          |       98      |      435       |
# |                          Kanye_West                         |       79      |      428       |
# |                           Buddhism                          |      149      |      610       |
# |                        American_Idol                        |      127      |      802       |
# |                             Dog                             |       75      |      392       |
# |               2008_Summer_Olympics_torch_relay              |       74      |      500       |
# |                    Alfred_North_Whitehead                   |       47      |      317       |
# |             Financial_crisis_of_2007%E2%80%9308             |       79      |      390       |
# |                    Saint_Barth%C3%A9lemy                    |       24      |      120       |
# |                            Genome                           |       25      |       76       |
# |                     Comprehensive_school                    |       24      |       73       |
# |                    Republic_of_the_Congo                    |       39      |      145       |
# |                        Prime_minister                       |       35      |      100       |
# |                   Institute_of_technology                   |       77      |      154       |
# |                       Wayback_Machine                       |       26      |       79       |
# |                        Dutch_Republic                       |       21      |       68       |
# |                          Symbiosis                          |       23      |       65       |
# |                    Canadian_Armed_Forces                    |       45      |      179       |
# |                    Cardinal_(Catholicism)                   |       43      |      117       |
# |                      Iranian_languages                      |       21      |       65       |
# |                           Lighting                          |       57      |      141       |
# |  Separation_of_powers_under_the_United_States_Constitution  |       27      |       88       |
# |                         Architecture                        |       38      |      185       |
# |                   Human_Development_Index                   |       31      |       82       |
# |                       Southern_Europe                       |       25      |       89       |
# |                        BBC_Television                       |       31      |      111       |
# |                    Arnold_Schwarzenegger                    |       86      |      221       |
# |                           Plymouth                          |       81      |      367       |
# |                            Heresy                           |       29      |       93       |
# |                         Warsaw_Pact                         |       22      |       52       |
# |                         Materialism                         |       27      |       54       |
# |                          Space_Race                         |       70      |      186       |
# |                             Pub                             |       90      |      377       |
# |                          Christian                          |       26      |       84       |
# |                   Sony_Music_Entertainment                  |       32      |       85       |
# |                        Oklahoma_City                        |       82      |      179       |
# |                       Hunter-gatherer                       |       34      |      144       |
# |                United_Nations_Population_Fund               |       22      |       99       |
# |         Russian_Soviet_Federative_Socialist_Republic        |       34      |      175       |
# |                      Universal_Studios                      |       42      |      201       |
# |                    Alexander_Graham_Bell                    |       74      |      325       |
# |                  Internet_service_provider                  |       21      |       82       |
# |                            Comics                           |       36      |      140       |
# |                         Saint_Helena                        |       82      |      313       |
# |                     Aspirated_consonant                     |       34      |       90       |
# |                           Hydrogen                          |       60      |      174       |
# |                         Web_browser                         |       24      |       72       |
# |                            Boston                           |       79      |      362       |
# |              BeiDou_Navigation_Satellite_System             |       34      |      144       |
# |                          Canon_law                          |       22      |      105       |
# |                  Communications_in_Somalia                  |       25      |      112       |
# |                       Catalan_language                      |       78      |      341       |
# |                      Estonian_language                      |       33      |      130       |
# |                            Paper                            |       31      |      108       |
# |                    Arena_Football_League                    |       55      |      272       |
# |                   Adult_contemporary_music                  |       53      |      216       |
# |                            Matter                           |       5       |       24       |
# |                      Westminster_Abbey                      |       46      |      202       |
# |                           Nanjing                           |       66      |      317       |
# |                             Bern                            |       52      |      181       |
# |                     Daylight_saving_time                    |       63      |      273       |
# |            Royal_Institute_of_British_Architects            |       27      |      120       |
# |         National_Archives_and_Records_Administration        |       28      |      106       |
# |                       Tristan_da_Cunha                      |       16      |       44       |
# |                     University_of_Kansas                    |       36      |      161       |
# |                     Political_corruption                    |       57      |      195       |
# |                           Dialect                           |       44      |      165       |
# |                       Classical_music                       |       68      |      314       |
# |                            Slavs                            |       49      |      206       |
# |                         Southampton                         |       95      |      426       |
# |                            Treaty                           |       57      |      281       |
# |                       Josip_Broz_Tito                       |       67      |      326       |
# |                       Marshall_Islands                      |       51      |      277       |
# |                           Szlachta                          |       63      |      276       |
# |                            Virgil                           |       23      |       96       |
# |                             Alps                            |       87      |      346       |
# |                             Gene                            |       56      |      279       |
# |                        Guinea-Bissau                        |       50      |      243       |
# |            List_of_numbered_streets_in_Manhattan            |       50      |      213       |
# |                            Brain                            |       64      |      222       |
# |                          Near_East                          |       59      |      229       |
# |                           Zhejiang                          |       38      |      189       |
# |             Ministry_of_Defence_(United_Kingdom)            |       25      |      111       |
# |                  High-definition_television                 |       46      |      204       |
# |                             Wood                            |       70      |      328       |
# |                           Somalis                           |       71      |      306       |
# |                         Middle_Ages                         |       93      |      452       |
# |                          Phonology                          |       23      |       89       |
# |                           Computer                          |       80      |      224       |
# |                         Black_people                        |       61      |      287       |
# |                          The_Times                          |       53      |      211       |
# |                          New_Delhi                          |       52      |      256       |
# |                    Imamah_(Shia_doctrine)                   |       14      |       69       |
# |                        Bird_migration                       |       56      |      245       |
# |                  Atlantic_City,_New_Jersey                  |       47      |      234       |
# |                          Immunology                         |       18      |       85       |
# |                             MP3                             |       62      |      289       |
# |                         House_music                         |       44      |      200       |
# |                         Letter_case                         |       12      |       55       |
# |                      Chihuahua_(state)                      |       66      |      306       |
# |                        Pitch_(music)                        |       10      |       36       |
# |                England_national_football_team               |       12      |       60       |
# |                           Houston                           |       48      |      294       |
# |                            Copper                           |       31      |      155       |
# |                  Identity_(social_science)                  |       21      |       85       |
# |                       Himachal_Pradesh                      |       23      |      111       |
# |                        Communication                        |       12      |       57       |
# |                            Grape                            |       10      |       48       |
# |                      Computer_security                      |       25      |      117       |
# |                       Orthodox_Judaism                      |       25      |      115       |
# |                            Animal                           |       17      |       79       |
# |                             Beer                            |       34      |      165       |
# |        Race_and_ethnicity_in_the_United_States_Census       |       12      |       52       |
# |                     United_States_dollar                    |       32      |      159       |
# |                   Imperial_College_London                   |       25      |      150       |
# |                          Gymnastics                         |       23      |      117       |
# |                           Hanover                           |       21      |      105       |
# |                           Emotion                           |       44      |      193       |
# |                         FC_Barcelona                        |       50      |      268       |
# |                         Everton_F.C.                        |       24      |      113       |
# |                         Old_English                         |       22      |      103       |
# |                       Aircraft_carrier                      |       34      |      167       |
# |               Federal_Aviation_Administration               |       12      |       55       |
# |                          Lancashire                         |       20      |       97       |
# |                           Mesozoic                          |       16      |       80       |
# |                      Videoconferencing                      |       21      |      102       |
# |                      Gregorian_calendar                     |       23      |      112       |
# |                           Xbox_360                          |       26      |      127       |
# |            Military_history_of_the_United_States            |       42      |      208       |
# |                          Hard_rock                          |       25      |      124       |
# |                         Great_Plains                        |       13      |       47       |
# |                           Infrared                          |       20      |       85       |
# |                         Biodiversity                        |       32      |      143       |
# |                            ASCII                            |       26      |      110       |
# |                          Digestion                          |       18      |       85       |
# |               Federal_Bureau_of_Investigation               |       45      |      221       |
# |                         Adolescence                         |       78      |      329       |
# |                          Antarctica                         |       44      |      230       |
# |                    Mary_(mother_of_Jesus)                   |       38      |      178       |
# |                          Melbourne                          |       64      |      315       |
# |                    John,_King_of_England                    |       76      |      250       |
# |                          Macintosh                          |       49      |      247       |
# |                    Anti-aircraft_warfare                    |       70      |      340       |
# |                           Sanskrit                          |       22      |      138       |
# |                           Valencia                          |       51      |      250       |
# |                       General_Electric                      |       16      |       79       |
# |                      United_States_Army                     |       34      |      142       |
# |                     Franco-Prussian_War                     |       58      |      287       |
# |                           Eritrea                           |       40      |      197       |
# |                           Uranium                           |       40      |      187       |
# |                 Order_of_the_British_Empire                 |       13      |       63       |
# |                     Age_of_Enlightenment                    |       83      |      361       |
# |                       Circadian_rhythm                      |       22      |      109       |
# |                         Elizabeth_II                        |       45      |      222       |
# |                      Sexual_orientation                     |       53      |      297       |
# |                             Dell                            |       45      |      199       |
# |           Capital_punishment_in_the_United_States           |       46      |      211       |
# |                Nintendo_Entertainment_System                |       44      |      193       |
# |                        Ashkenazi_Jews                       |       50      |      194       |
# |                   Athanasius_of_Alexandria                  |       36      |      197       |
# |                           Seattle                           |       52      |      260       |
# |                            Memory                           |       32      |      133       |
# |                     Multiracial_American                    |       44      |      270       |
# |                   Pharmaceutical_industry                   |       44      |      368       |
# |                      Umayyad_Caliphate                      |       35      |      145       |
# |                           Asphalt                           |       36      |      179       |
# |                        Queen_Victoria                       |       42      |      680       |
# |                         Freemasonry                         |       37      |      271       |
# |                            Israel                           |       99      |      297       |
# |                      Hellenistic_period                     |       94      |      469       |
# |                           Napoleon                          |       89      |      458       |
# |              Bill_%26_Melinda_Gates_Foundation              |       21      |       81       |
# |                   Northwestern_University                   |       44      |      227       |
# |                           Hokkien                           |       21      |      107       |
# |                          Montevideo                         |       70      |      247       |
# |                           Poultry                           |       31      |      140       |
# |                         Arsenal_F.C.                        |       34      |      174       |
# |                        Dutch_language                       |       51      |      250       |
# |                      Buckingham_Palace                      |       28      |      254       |
# |                   Incandescent_light_bulb                   |       42      |      196       |
# |                           Clothing                          |       21      |      105       |
# |                         Chicago_Cubs                        |       63      |      210       |
# |                      States_of_Germany                      |       23      |      125       |
# |                          Korean_War                         |       75      |      348       |
# |                      Royal_Dutch_Shell                      |       25      |      128       |
# |                    Copyright_infringement                   |       39      |      182       |
# |                            Greece                           |       95      |      406       |
# |                            Mammal                           |       24      |       88       |
# |                      East_India_Company                     |       31      |      169       |
# |                        Southeast_Asia                       |       26      |      122       |
# |                    Professional_wrestling                   |       61      |      245       |
# |                          Film_speed                         |       26      |      128       |
# |                         Mexico_City                         |       87      |      390       |
# |                           Germans                           |       32      |      204       |
# |                    New_Haven,_Connecticut                   |       66      |      602       |
# |                   Brigham_Young_University                  |       37      |      226       |
# |                    Myocardial_infarction                    |       5       |       22       |
# |                       Department_store                      |       40      |      178       |
# |                    Intellectual_property                    |       21      |       94       |
# |                           Florida                           |       35      |      141       |
# |                         Queen_(band)                        |       59      |      269       |
# |                       Presbyterianism                       |       38      |      133       |
# |                          Thuringia                          |       29      |      131       |
# |                          Predation                          |       26      |      153       |
# |                        Marvel_Comics                        |       25      |      123       |
# |                        British_Empire                       |       60      |      293       |
# |                            Botany                           |       51      |      233       |
# |                    Madonna_(entertainer)                    |       76      |      349       |
# |                            London                           |       77      |      379       |
# |                   Law_of_the_United_States                  |       27      |      197       |
# |                           Myanmar                           |       73      |      339       |
# |                             Jews                            |       36      |      130       |
# |                            Cotton                           |       30      |      150       |
# |                       Data_compression                      |       26      |       85       |
# |                   The_Sun_(United_Kingdom)                  |       49      |      247       |
# |                           Carnival                          |       52      |      273       |
# |                          Pesticide                          |       26      |      112       |
# |                           Somerset                          |       37      |      149       |
# |                       Yale_University                       |       46      |      222       |
# |                       Late_Middle_Ages                      |       40      |      192       |
# |                     Ann_Arbor,_Michigan                     |       32      |      107       |
# |                     Gothic_architecture                     |       40      |      196       |
# |                            Cubism                           |       39      |      129       |
# |                     Political_philosophy                    |       21      |       73       |
# |                            Alloy                            |       22      |       96       |
# |                        Norfolk_Island                       |       30      |      148       |
# |                         Edmund_Burke                        |       40      |      186       |
# |                            Samoa                            |       25      |      123       |
# |                         Pope_Paul_VI                        |       55      |      271       |
# |                          George_VI                          |       23      |      100       |
# |                        Electric_motor                       |       42      |      183       |
# |                         Switzerland                         |       77      |      353       |
# |                             Mali                            |       22      |      110       |
# |                    Nonprofit_organization                   |       24      |      118       |
# |                   Raleigh,_North_Carolina                   |       34      |      169       |
# |                          Nutrition                          |       56      |      275       |
# |                         Crimean_War                         |       62      |      287       |
# |                          Literature                         |       23      |      110       |
# |                           Avicenna                          |       35      |      161       |
# |                      Chinese_characters                     |       56      |      168       |
# |                           Bermuda                           |       47      |      228       |
# |                           Nigeria                           |       55      |      254       |
# |                           Utrecht                           |       27      |      104       |
# |                       John_von_Neumann                      |       63      |      221       |
# |               Molotov%E2%80%93Ribbentrop_Pact               |       44      |      151       |
# |                          Capacitor                          |       37      |      185       |
# |                      History_of_science                     |       67      |      309       |
# |                        Czech_language                       |       28      |      149       |
# |                           Digimon                           |       21      |      108       |
# |                           Glacier                           |       23      |      102       |
# |                       Planck_constant                       |       24      |      178       |
# |                           Comcast                           |       27      |      131       |
# |                         Tuberculosis                        |       31      |      151       |
# |           Affirmative_action_in_the_United_States           |       48      |      227       |
# |                            FA_Cup                           |       32      |      159       |
# |                            Alsace                           |       27      |       93       |
# |                           Baptists                          |       23      |      101       |
# |                         Child_labour                        |       61      |      236       |
# |                        North_Carolina                       |       61      |      297       |
# |                         Heian_period                        |       24      |       96       |
# |                   On_the_Origin_of_Species                  |       59      |      262       |
# |               Dissolution_of_the_Soviet_Union               |       67      |      300       |
# |                     Crucifixion_of_Jesus                    |       32      |      159       |
# |                            Miami                            |       45      |      221       |
# |                        Supreme_court                        |       23      |      108       |
# |                      Textual_criticism                      |       32      |      142       |
# |                      Gramophone_record                      |       85      |      404       |
# |                    Turner_Classic_Movies                    |       23      |      101       |
# |                       Hindu_philosophy                      |       25      |      121       |
# |                       Political_party                       |       27      |      110       |
# |                          A_cappella                         |       23      |      104       |
# |                       Dominican_Order                       |       44      |      203       |
# |                         Eton_College                        |       43      |      172       |
# |                         Cork_(city)                         |       30      |      144       |
# |                          Federalism                         |       38      |      161       |
# |                       Galicia_(Spain)                       |       50      |      159       |
# |                            Green                            |       27      |      101       |
# |                             USB                             |       66      |      235       |
# |                           Sichuan                           |       25      |      113       |
# |                           Unicode                           |       33      |      130       |
# |                           Detroit                           |       79      |      330       |
# |                           Culture                           |       24      |       79       |
# |                            Sahara                           |       25      |       85       |
# |                         Rule_of_law                         |       24      |      114       |
# |                            Tibet                            |       39      |      157       |
# |                       Exhibition_game                       |       21      |       98       |
# |                          Strasbourg                         |       34      |      156       |
# |                           Oklahoma                          |       55      |      271       |
# |                       History_of_India                      |       78      |      389       |
# |                      Gamal_Abdel_Nasser                     |       95      |      433       |
# |                       Pope_John_XXIII                       |       25      |      110       |
# |                             Time                            |       29      |      127       |
# |                    European_Central_Bank                    |       28      |      127       |
# |           St._John%27s,_Newfoundland_and_Labrador           |       31      |      133       |
# |                        PlayStation_3                        |       44      |      213       |
# |                         Royal_assent                        |       38      |      181       |
# |                     Group_(mathematics)                     |       30      |      111       |
# |                   Central_African_Republic                  |       23      |      115       |
# |                            Asthma                           |       25      |      111       |
# |                          LaserDisc                          |       50      |      182       |
# |                           Annelid                           |       35      |      159       |
# |                             God                             |       24      |      176       |
# |                        War_on_Terror                        |       31      |      146       |
# |                      Labour_Party_(UK)                      |       24      |       81       |
# |                           Estonia                           |       72      |      298       |
# |                        Serbo-Croatian                       |       22      |       94       |
# |                            Alaska                           |       48      |      187       |
# |                         Karl_Popper                         |       43      |      180       |
# |                           Mandolin                          |       43      |      210       |
# |                            Insect                           |       60      |      343       |
# |                 Race_(human_categorization)                 |       65      |      325       |
# |                            Paris                            |       94      |      389       |
# |                            Apollo                           |       52      |      182       |
# |          United_States_presidential_election,_2004          |       26      |      127       |
# |                             IBM                             |       26      |      135       |
# |                  Liberal_Party_of_Australia                 |       26      |       91       |
# |                           Samurai                           |       50      |      235       |
# |                       Software_testing                      |       29      |       99       |
# |                            Glass                            |       26      |      119       |
# |              Renewable_energy_commercialization             |       40      |      130       |
# |                           Palermo                           |       24      |       92       |
# |                             Zinc                            |       38      |      185       |
# |                  Neoclassical_architecture                  |       22      |       94       |
# |                        CBC_Television                       |       25      |       85       |
# |                    Appalachian_Mountains                    |       16      |       60       |
# |                            Energy                           |       33      |      119       |
# |                         East_Prussia                        |       27      |       90       |
# |                        Ottoman_Empire                       |       69      |      340       |
# |                 Philosophy_of_space_and_time                |       24      |      109       |
# |                          Neolithic                          |       23      |       91       |
# |                       Friedrich_Hayek                       |       50      |      227       |
# |                           Diarrhea                          |       21      |       76       |
# |                           Madrasa                           |       35      |      160       |
# |                         Philadelphia                        |       59      |      239       |
# |                          John_Kerry                         |       52      |      247       |
# |                          Rajasthan                          |       24      |      119       |
# |                             Guam                            |       36      |      125       |
# |                          Empiricism                         |       25      |      121       |
# |                           Idealism                          |       29      |      133       |
# |                          Education                          |       34      |      108       |
# |                          Tennessee                          |       50      |      232       |
# |                          Post-punk                          |       22      |      215       |
# |                      Canadian_football                      |       21      |       92       |
# |                      Seven_Years%27_War                     |       60      |      301       |
# |                       Richard_Feynman                       |       32      |      151       |
# |                       Muammar_Gaddafi                       |       76      |      489       |
# |                            Cyprus                           |       59      |      248       |
# |                       Steven_Spielberg                      |       49      |      282       |
# |                           Elevator                          |       52      |      239       |
# |                           Neptune                           |       36      |      174       |
# |                Railway_electrification_system               |       34      |      147       |
# |            Spanish_language_in_the_United_States            |       22      |      103       |
# |                  Charleston,_South_Carolina                 |       48      |      252       |
# |                             Red                             |       48      |      239       |
# |                          The_Blitz                          |       92      |      414       |
# |                    Endangered_Species_Act                   |       31      |      121       |
# |                            Vacuum                           |       30      |      127       |
# |                         Han_dynasty                         |       65      |      323       |
# |                            Greeks                           |       44      |      211       |
# |                            Quran                            |       43      |      182       |
# |                         Great_power                         |       21      |      102       |
# |                Geography_of_the_United_States               |       21      |       91       |
# |                         Compact_disc                        |       25      |      122       |
# |                          Transistor                         |       23      |      109       |
# |                        Modern_history                       |       88      |      448       |
# |                          51st_state                         |       32      |      135       |
# |                       Antenna_(radio)                       |       74      |      305       |
# |                       Flowering_plant                       |       23      |      112       |
# |                          Hyderabad                          |       53      |      260       |
# |                   Santa_Monica,_California                  |       22      |      110       |
# |              Washington_University_in_St._Louis             |       35      |      170       |
# |                 Central_Intelligence_Agency                 |       16      |       65       |
# |                             Pain                            |       33      |      161       |
# |                           Database                          |       32      |      125       |
# |                       Tucson,_Arizona                       |       52      |      370       |
# |                           Armenia                           |       57      |      241       |
# |                           Bacteria                          |       51      |      216       |
# |                    Printed_circuit_board                    |       35      |      171       |
# |                        Premier_League                       |       40      |      358       |
# |                        Roman_Republic                       |       82      |      392       |
# |                         Pacific_War                         |       71      |      391       |
# |                      Richmond,_Virginia                     |       61      |      324       |
# |                          San_Diego                          |       48      |      234       |
# |                         Muslim_world                        |       27      |      128       |
# |                             Iran                            |       60      |      282       |
# |                        British_Isles                        |       34      |      156       |
# |                     Association_football                    |       28      |      127       |
# |                    Georgian_architecture                    |       21      |       93       |
# |                           Liberia                           |       23      |      111       |
# |                          Windows_8                          |       48      |      202       |
# |                          Swaziland                          |       27      |      125       |
# |                         Translation                         |       29      |      141       |
# |                           Airport                           |       25      |       96       |
# |                        Kievan_Rus%27                        |       39      |      131       |
# |             Super_Nintendo_Entertainment_System             |       24      |      113       |
# |                            Sumer                            |       32      |      160       |
# |                            Tuvalu                           |       61      |      299       |
# |                    Immaculate_Conception                    |       22      |      104       |
# |                           Namibia                           |       38      |      179       |
# |                       Russian_language                      |       31      |      136       |
# |                   United_States_Air_Force                   |       57      |      241       |
# |                     Light-emitting_diode                    |       43      |      200       |
# |                             Bird                            |       62      |      230       |
# |                         Qing_dynasty                        |       81      |      324       |
# |              Indigenous_peoples_of_the_Americas             |       56      |      285       |
# |                            Egypt                            |       64      |      248       |
# |                            Mosaic                           |       64      |      311       |
# |                          University                         |       27      |      124       |
# |                   Religion_in_ancient_Rome                  |       81      |      405       |
# |                           YouTube                           |       34      |      162       |
# |     Separation_of_church_and_state_in_the_United_States     |       41      |      202       |
# |                        Protestantism                        |       75      |      369       |
# |                        Bras%C3%ADlia                        |       23      |      108       |
# |                      Economy_of_Greece                      |       29      |      145       |
# | Party_leaders_of_the_United_States_House_of_Representatives |       31      |      106       |
# |                          Armenians                          |       25      |      118       |
# |                    Jehovah%27s_Witnesses                    |       46      |      226       |
# |                     Dwight_D._Eisenhower                    |       90      |      430       |
# |                          The_Bronx                          |       57      |      271       |
# |                           Humanism                          |       30      |      124       |
# |                 Geological_history_of_Earth                 |       25      |      129       |
# |                            Police                           |       36      |      168       |
# |                       Punjab,_Pakistan                      |       26      |      126       |
# |                          Infection                          |       30      |      144       |
# |                           Hunting                           |       36      |      357       |
# |                          Kathmandu                          |       58      |      276       |
# +-------------------------------------------------------------+---------------+----------------+

# %%
# Step 1: Aggregate data - Count unique contexts for each title
title_context_count = defaultdict(set)

for entry in train_data:
    title = entry['title']
    context = entry['context']
    title_context_count[title].add(context)

# Step 2: Convert the set of contexts into counts
title_context_count = {title: len(contexts) for title, contexts in title_context_count.items()}

# Step 3: Sort the titles by the number of contexts (descending order)
sorted_titles = sorted(title_context_count.items(), key=lambda x: x[1], reverse=True)

# Step 4: Prepare data for the pie chart (limiting to top N titles, e.g., top 10)
top_n = 5
top_titles = [title for title, count in sorted_titles[:top_n]]
top_context_counts = [count for title, count in sorted_titles[:top_n]]

# Step 5: Define a function to show number of contexts instead of percentage
def make_autopct(context_counts):
    def autopct(pct):
        total = sum(context_counts)
        val = int(round(pct * total / 100.0))
        return f'{val} contexts'
    return autopct

# Step 6: Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_context_counts, labels=top_titles, autopct=make_autopct(top_context_counts), startangle=0, colors=plt.cm.Paired.colors)
plt.title(f'Top {top_n} Titles with the Most Unique Contexts')
plt.axis('equal')
plt.show()

# %%
from wordcloud import WordCloud

# Most common words in contexts
all_contexts = ' '.join([ex['context'] for ex in train_data])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_contexts)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words in Contexts')
plt.show()

# Most common words in questions
all_questions = ' '.join([ex['question'] for ex in train_data])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_questions)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words in Questions')
plt.show()

# %%
from transformers import DistilBertTokenizer, DistilBertForQuestionAnswering, AutoTokenizer

# distilbert_tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
distilbert_model = DistilBertForQuestionAnswering.from_pretrained('distilbert-base-uncased')
distilbert_tokenizer = AutoTokenizer.from_pretrained("distilbert/distilbert-base-uncased")
# Out:
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# Below method borrowed from the following resource: [HuggingFace QuestionAnswering Documentation --> Preprocess](https://huggingface.co/docs/transformers/en/tasks/question_answering#preprocess)

# %%
def preprocess_function(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = distilbert_tokenizer(
        questions,
        examples["context"],
        max_length=384,
        truncation="only_second",
        return_offsets_mapping=True,
        padding="max_length",
    )

    offset_mapping = inputs.pop("offset_mapping")
    answers = examples["answers"]
    start_positions = []
    end_positions = []

    for i, offset in enumerate(offset_mapping):
        answer = answers[i]
        start_char = answer["answer_start"][0]
        end_char = answer["answer_start"][0] + len(answer["text"][0])
        sequence_ids = inputs.sequence_ids(i)

        # Find the start and end of the context
        idx = 0
        while sequence_ids[idx] != 1:
            idx += 1
        context_start = idx
        while sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1

        # If the answer is not fully inside the context, label it (0, 0)
        if offset[context_start][0] > end_char or offset[context_end][1] < start_char:
            start_positions.append(0)
            end_positions.append(0)
        else:
            # Otherwise it's the start and end token positions
            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

# %%
tokenized_squad_train = train_data.map(preprocess_function, batched=True, remove_columns=train_data.column_names)
tokenized_squad_validation = validation_data.map(preprocess_function, batched=True, remove_columns=validation_data.column_names)

# %% [markdown]
# Speeding up training time, here are 3 optimizations I used:
# fp16 --> mixed precision training to speed up computations
# increased batch size --> went from 16 to 32 to push my GPU harder since utilization was low (if you get an OutOfMemory Error, decrease batch size)
# increased dataloader workers

# %%
from transformers import DefaultDataCollator, TrainingArguments, Trainer

data_collator = DefaultDataCollator()

training_args = TrainingArguments(
    output_dir="my_awesome_qa_model",
    eval_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    num_train_epochs=3,
    weight_decay=0.01,
    fp16=True,
    dataloader_num_workers=4
)

trainer = Trainer(
    model=distilbert_model,
    args=training_args,
    train_dataset=tokenized_squad_train,
    eval_dataset=tokenized_squad_validation,
    tokenizer=distilbert_tokenizer,
    data_collator=data_collator,
)

trainer.train()
# Out:
#   0%|          | 0/8214 [00:00<?, ?it/s]
# {'loss': 2.7474, 'grad_norm': 13.636909484863281, 'learning_rate': 1.8787436084733382e-05, 'epoch': 0.18}
# {'loss': 1.6034, 'grad_norm': 11.89020824432373, 'learning_rate': 1.7570002434867303e-05, 'epoch': 0.37}
# {'loss': 1.4662, 'grad_norm': 10.393138885498047, 'learning_rate': 1.635256878500122e-05, 'epoch': 0.55}
# {'loss': 1.3523, 'grad_norm': 11.487044334411621, 'learning_rate': 1.5135135135135138e-05, 'epoch': 0.73}
# {'loss': 1.2931, 'grad_norm': 10.785930633544922, 'learning_rate': 1.3917701485269055e-05, 'epoch': 0.91}
#   0%|          | 0/331 [00:00<?, ?it/s]
# {'eval_loss': 1.1968625783920288, 'eval_runtime': 44.7998, 'eval_samples_per_second': 235.939, 'eval_steps_per_second': 7.388, 'epoch': 1.0}
# {'loss': 1.1493, 'grad_norm': 10.354741096496582, 'learning_rate': 1.270026783540297e-05, 'epoch': 1.1}
# {'loss': 1.0827, 'grad_norm': 10.445509910583496, 'learning_rate': 1.1485269052836621e-05, 'epoch': 1.28}
# {'loss': 1.0655, 'grad_norm': 9.327767372131348, 'learning_rate': 1.027027027027027e-05, 'epoch': 1.46}
# {'loss': 1.0323, 'grad_norm': 9.662849426269531, 'learning_rate': 9.052836620404189e-06, 'epoch': 1.64}
# {'loss': 1.0133, 'grad_norm': 8.433852195739746, 'learning_rate': 7.835402970538106e-06, 'epoch': 1.83}
#   0%|          | 0/331 [00:00<?, ?it/s]
# {'eval_loss': 1.1243680715560913, 'eval_runtime': 44.2889, 'eval_samples_per_second': 238.66, 'eval_steps_per_second': 7.474, 'epoch': 2.0}
# {'loss': 1.0378, 'grad_norm': 12.375251770019531, 'learning_rate': 6.617969320672024e-06, 'epoch': 2.01}
# {'loss': 0.8806, 'grad_norm': 8.914721488952637, 'learning_rate': 5.400535670805942e-06, 'epoch': 2.19}
# {'loss': 0.8838, 'grad_norm': 10.389485359191895, 'learning_rate': 4.185536888239592e-06, 'epoch': 2.37}
# {'loss': 0.8846, 'grad_norm': 8.80484390258789, 'learning_rate': 2.9705381056732415e-06, 'epoch': 2.56}
# {'loss': 0.8598, 'grad_norm': 12.868570327758789, 'learning_rate': 1.7531044558071586e-06, 'epoch': 2.74}
# {'loss': 0.8627, 'grad_norm': 12.055418014526367, 'learning_rate': 5.356708059410762e-07, 'epoch': 2.92}
#   0%|          | 0/331 [00:00<?, ?it/s]
# {'eval_loss': 1.1361591815948486, 'eval_runtime': 45.552, 'eval_samples_per_second': 232.042, 'eval_steps_per_second': 7.266, 'epoch': 3.0}
# {'train_runtime': 2906.2238, 'train_samples_per_second': 90.426, 'train_steps_per_second': 2.826, 'train_loss': 1.191826591185186, 'epoch': 3.0}
# TrainOutput(global_step=8214, training_loss=1.191826591185186, metrics={'train_runtime': 2906.2238, 'train_samples_per_second': 90.426, 'train_steps_per_second': 2.826, 'total_flos': 2.575143204683213e+16, 'train_loss': 1.191826591185186, 'epoch': 3.0})

# %% [markdown]
# Down below when trying to perform inference, I was getting a ValueError so I am re-saving the model to correct it.

# %%
distilbert_model.save_pretrained("my_awesome_qa_model")
distilbert_tokenizer.save_pretrained("my_awesome_qa_model")
# Out:
# ('my_awesome_qa_model\\tokenizer_config.json',
#  'my_awesome_qa_model\\special_tokens_map.json',
#  'my_awesome_qa_model\\vocab.txt',
#  'my_awesome_qa_model\\added_tokens.json',
#  'my_awesome_qa_model\\tokenizer.json')

# %%
question = "How many programming languages does BLOOM support?"
context = "BLOOM has 176 billion parameters and can generate text in 46 languages natural languages and 13 programming languages."

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering", model="my_awesome_qa_model", device=device)
question_answerer(question=question, context=context)
# Out:
# {'score': 0.7784110307693481, 'start': 93, 'end': 95, 'answer': '13'}
